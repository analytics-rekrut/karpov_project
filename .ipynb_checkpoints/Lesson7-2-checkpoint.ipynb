# %%
import pandas as pd
df_1=pd.read_csv(r'F:\Lessons\Lesson7\step_1.csv', sep=',')
df_1
# Out:
#          date user_type  visits
# 0  2020-06-15    People   417.0
# 1  2020-06-15    Robots   177.0
# 2  2020-06-16    People   472.0
# 3  2020-06-16    Robots    91.0
# 4  2020-06-17    People   475.0
# 5  2020-06-17    Robots   138.0

# %%
import seaborn as sns
sns.barplot(x='date', y='visits', data=df_1, hue='user_type')
# Out:
# <AxesSubplot:xlabel='date', ylabel='visits'>

# %%
df_2=pd.read_csv(r'F:\Lessons\Lesson7\step_2.csv', sep=',')
df_2
# Out:
#           date             browser  visits
# 0   2020-06-15       Google Chrome   354.0
# 1   2020-06-15             Firefox    58.0
# 2   2020-06-15      Yandex Browser    54.0
# 3   2020-06-15              Safari    41.0
# 4   2020-06-15       Chrome Mobile    31.0
# 5   2020-06-15               Opera    16.0
# 6   2020-06-15       Mobile Safari    16.0
# 7   2020-06-15    Samsung Internet     9.0
# 8   2020-06-15                Edge     5.0
# 9   2020-06-15               UCWEB     4.0
# 10  2020-06-15            Chromium     2.0
# 11  2020-06-15     Android Browser     1.0
# 12  2020-06-15  Yandex: mobile app     1.0
# 13  2020-06-15             Vivaldi     1.0
# 14  2020-06-15              CocCoc     1.0

# %%
res=df_2.query("browser=='Google Chrome'").visits/df_2.visits.sum()*100
round(res)
# Out:
# 0    60.0
# Name: visits, dtype: float64

# %%
import pandas as pd
df_3=pd.read_csv(r'F:\Lessons\lesson7\step_3.csv', sep=',')

# %%
df_3_sum=df_3.groupby('browser').agg({'visits':'sum'})

# %%
df_3_robots=df_3.query("user_type=='Robots'").sort_values("browser").set_index("browser")

# %%
tmp=df_3_robots.visits/df_3_sum.visits #Соотношение ботов и людей

tmp.dropna().sort_values()
# Out:
# browser
# Mobile Safari       0.062500
# Samsung Internet    0.111111
# Yandex Browser      0.129630
# Edge                0.200000
# Google Chrome       0.293785
# Opera               0.312500
# Chromium            0.500000
# Firefox             0.534483
# Safari              0.536585
# UCWEB               1.000000
# Name: visits, dtype: float64

# %%
import pandas as pd
df_4=pd.read_csv(r'F:\Lessons\lesson7\step_4.csv', sep=',')
df_4.head()
summ=df_4.visits.sum()
summ
# Out:
# 594.0

# %%
df_4_sum = df_4.groupby('browser', as_index=False).agg({'visits':'sum'}) 
df_4_sum
# Out:
#                browser  visits
# 0      Android Browser     1.0
# 1        Chrome Mobile    31.0
# 2             Chromium     2.0
# 3               CocCoc     1.0
# 4                 Edge     5.0
# 5              Firefox    58.0
# 6        Google Chrome   354.0
# 7        Mobile Safari    16.0
# 8                Opera    16.0
# 9               Safari    41.0
# 10    Samsung Internet     9.0
# 11               UCWEB     4.0
# 12             Vivaldi     1.0
# 13      Yandex Browser    54.0
# 14  Yandex: mobile app     1.0

# %%
df_4=df_4.merge(df_4_sum, how='inner', on='browser') 
df_4
# Out:
#           date             browser user_type  visits_x  visits_y
# 0   2020-06-15       Google Chrome    People     250.0     354.0
# 1   2020-06-15       Google Chrome    Robots     104.0     354.0
# 2   2020-06-15      Yandex Browser    People      47.0      54.0
# 3   2020-06-15      Yandex Browser    Robots       7.0      54.0
# 4   2020-06-15             Firefox    Robots      31.0      58.0
# 5   2020-06-15             Firefox    People      27.0      58.0
# 6   2020-06-15       Chrome Mobile    People      31.0      31.0
# 7   2020-06-15              Safari    Robots      22.0      41.0
# 8   2020-06-15              Safari    People      19.0      41.0
# 9   2020-06-15       Mobile Safari    People      15.0      16.0
# 10  2020-06-15       Mobile Safari    Robots       1.0      16.0
# 11  2020-06-15               Opera    People      11.0      16.0
# 12  2020-06-15               Opera    Robots       5.0      16.0
# ...

# %%
df_4['Key']=df_4.visits_x/df_4.visits_y*100
df_4.head()
# Out:
#          date         browser user_type  visits_x  visits_y        Key
# 0  2020-06-15   Google Chrome    People     250.0     354.0  70.621469
# 1  2020-06-15   Google Chrome    Robots     104.0     354.0  29.378531
# 2  2020-06-15  Yandex Browser    People      47.0      54.0  87.037037
# 3  2020-06-15  Yandex Browser    Robots       7.0      54.0  12.962963
# 4  2020-06-15         Firefox    Robots      31.0      58.0  53.448276

# %%
df_4['BigKey']=df_4.visits_x/summ*100

# %%
round(df_4.query("browser=='Safari' and user_type=='People' "), 1)
# Out:
#          date browser user_type  visits_x  visits_y   Key  BigKey
# 8  2020-06-15  Safari    People      19.0      41.0  46.3     3.2
