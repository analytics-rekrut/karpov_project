# %%
import pandas as pd

# %%
df=pd.read_csv(r'F:\Lessons\Math\\conversion.csv', sep=',')

# %%
df.head(10)
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
# 5  708820              916          103929  30-34      M        29
# 6  708889              916          103940  30-34      M        15
# 7  708895              916          103941  30-34      M        16
# 8  708953              916          103951  30-34      M        27
# 9  708958              916          103952  30-34      M        28
#
#    Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion
# 0         7350       1   1.43                 2                    1
# 1        17861       2   1.82                 2                    0
# ...

# %%
df.nunique()
# Out:
# ad_id                  1143
# xyz_campaign_id           3
# fb_campaign_id          691
# age                       4
# gender                    2
# interest                 40
# Impressions            1130
# Clicks                  183
# Spent                   869
# Total_Conversion         32
# Approved_Conversion      16
# dtype: int64

# %%
import numpy as np

# %%
a=np.log(df.groupby("fb_campaign_id").agg({'Impressions':'sum'}))

# %%
a
# Out:
#                 Impressions
# fb_campaign_id
# 103916             8.902456
# 103917             9.790375
# 103920             6.541030
# 103928             9.035034
# 103929             7.557473
# ...                     ...
# 179977            13.937527
# 179978            13.365386
# 179979            11.928546
# 179981            13.580108
# 179982            13.148345
#
# [691 rows x 1 columns]

# %%
import seaborn as sns

# %%
from scipy.stats import norm

# %%
ax = sns.distplot(a, fit=norm, kde=False, color='g')

# %%
df['CTR']=df.Clicks/df.Impressions
df
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# ...

# %%
ind=df['CTR'].idxmax()

# %%
df.iloc[ind]
# Out:
# ad_id                    738637
# xyz_campaign_id             936
# fb_campaign_id           109857
# age                       45-49
# gender                        F
# interest                     24
# Impressions                 944
# Clicks                        1
# Spent                      1.42
# Total_Conversion              1
# Approved_Conversion           0
# CTR                    0.001059
# Name: 150, dtype: object

# %%
b=df.query("xyz_campaign_id==916")

# %%
b
# Out:
#      ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0   708746              916          103916  30-34      M        15
# 1   708749              916          103917  30-34      M        16
# 2   708771              916          103920  30-34      M        20
# 3   708815              916          103928  30-34      M        28
# 4   708818              916          103928  30-34      M        28
# 5   708820              916          103929  30-34      M        29
# 6   708889              916          103940  30-34      M        15
# 7   708895              916          103941  30-34      M        16
# 8   708953              916          103951  30-34      M        27
# 9   708958              916          103952  30-34      M        28
# 10  708979              916          103955  30-34      M        31
# 11  709023              916          103962  30-34      M         7
# 12  709038              916          103965  30-34      M        16
# ...

# %%
bx = sns.distplot(b.CTR, bins=20 , kde=False, color='g') #это ёпа мать срез чтоб получить распроёбаное распределение
# Out:
# F:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import scipy

# %%
df['CPC']=df.Spent/df.Clicks

# %%
scipy.stats.iqr(df['CPC'], nan_policy='omit')
# Out:
# 0.2543636990499998
